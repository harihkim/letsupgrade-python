# %%
# Day4
# Question 1
n=1042000
while(n<=702648265):
  m=n
  sum=0
  while(m>0):
    digit=m%10
    sum=sum+(digit**len(str(m)))
    m=m//10
  if(n==num):
    print(n)
    break
  n+=1
# Out:
# 1741725
